# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np

voltages = np.genfromtxt('Builds/MacOSX/build/Debug/results.txt', delimiter=',')
plt.plot(voltages)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
